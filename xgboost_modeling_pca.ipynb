# %%
import mlp # Multi-layer perceptron classifier
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from workflow import do_workflow

from collections import Counter
import numpy as np

import xgboost as xgb
from sklearn.datasets import make_multilabel_classification
from sklearn.model_selection import train_test_split
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import accuracy_score

# %%
# Read train dataset and subset into train and validation
train_df = pd.read_csv("clean_train_reduced.csv")

x_train=train_df.sample(frac=0.8,random_state=200) #random state is a seed value
x_val=train_df.drop(x_train.index)
del train_df # For memory reasons

# Take out target variable
y_train = list(x_train.pop("pollutant"))
y_val = list(x_val.pop("pollutant"))

# %%
# One-hot encode the targets, to make it suitable for the softmax last layer
targets = ["Methane (CH4)", "Nitrogen oxides (NOX)", "Carbon dioxide (CO2)"] 
for i in range(len(y_train)):
    if y_train[i] == "Methane (CH4)": y_train[i] = [1,0,0]
    elif y_train[i] == "Nitrogen oxides (NOX)": y_train[i] = [0,1,0]
    else: y_train[i] = np.array([0,0,1])
#y_train = principalDf = pd.DataFrame(data = y_train, columns = ["y_train"])
y_train = np.array(y_train)

for i in range(len(y_val)):
    if y_val[i] == "Methane (CH4)": y_val[i] = [1,0,0]
    elif y_val[i] == "Nitrogen oxides (NOX)": y_val[i] = [0,1,0]
    else: y_val[i] = np.array([0,0,1])
#y_val = principalDf = pd.DataFrame(data = y_val, columns = ["y_val"])
y_val = np.array(y_val)

print(y_train.shape, y_val.shape)
# Out:
# (52502, 3) (13126, 3)

# %%
# Fine-tune an XGBoost model follwing this tutorial: https://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/#h2_6
best_model = do_workflow(
        dftrain=x_train,
        y_train=y_train,
        dftest=x_val,
        y_test=y_val,
        kfolds=2,
    )
# Out:
# Base model without tuning :
# Val accuracy: 63.23%
#
# Step 1 : Estimate numbers of trees...
# [0]	train-logloss:0.65548+0.00002	test-logloss:0.65589+0.00014
# [50]	train-logloss:0.39741+0.00080	test-logloss:0.41288+0.00047
# [100]	train-logloss:0.37257+0.00182	test-logloss:0.40565+0.00007
# [150]	train-logloss:0.35381+0.00203	test-logloss:0.40264+0.00018
# [200]	train-logloss:0.33664+0.00211	test-logloss:0.40026+0.00039
# [250]	train-logloss:0.32095+0.00159	test-logloss:0.39864+0.00033
# [300]	train-logloss:0.30661+0.00222	test-logloss:0.39716+0.00016
# [350]	train-logloss:0.29346+0.00161	test-logloss:0.39641+0.00053
# [400]	train-logloss:0.28133+0.00140	test-logloss:0.39591+0.00070
# [450]	train-logloss:0.27035+0.00112	test-logloss:0.39562+0.00063
# [500]	train-logloss:0.25983+0.00110	test-logloss:0.39533+0.00068
# [550]	train-logloss:0.24959+0.00087	test-logloss:0.39541+0.00089
# [568]	train-logloss:0.24642+0.00113	test-logloss:0.39541+0.00083
# Initial num_boost_round :  520
#
# Step 2 : Tune max_depth and min_child_weight...
# Fitting 2 folds for each of 15 candidates, totalling 30 fits
# [CV] END ....................max_depth=3, min_child_weight=4; total time= 2.6min
# [CV] END ....................max_depth=3, min_child_weight=3; total time= 2.6min
# [CV] END ....................max_depth=3, min_child_weight=4; total time= 2.6min
# [CV] END ....................max_depth=3, min_child_weight=3; total time= 2.6min
# [CV] END ....................max_depth=3, min_child_weight=1; total time= 2.6min
# [CV] END ....................max_depth=3, min_child_weight=2; total time= 2.6min
# [CV] END ....................max_depth=3, min_child_weight=1; total time= 2.6min
# [CV] END ....................max_depth=3, min_child_weight=2; total time= 2.6min
# [CV] END ....................max_depth=3, min_child_weight=5; total time= 2.5min
# [CV] END ....................max_depth=3, min_child_weight=5; total time= 2.5min
# [CV] END ....................max_depth=4, min_child_weight=3; total time= 3.6min
# [CV] END ....................max_depth=4, min_child_weight=3; total time= 3.6min
# [CV] END ....................max_depth=4, min_child_weight=2; total time= 3.6min
# [CV] END ....................max_depth=4, min_child_weight=2; total time= 3.6min
# [CV] END ....................max_depth=4, min_child_weight=1; total time= 3.6min
# [CV] END ....................max_depth=4, min_child_weight=1; total time= 3.6min
# [CV] END ....................max_depth=4, min_child_weight=4; total time= 3.4min
# [CV] END ....................max_depth=4, min_child_weight=4; total time= 3.4min
# [CV] END ....................max_depth=4, min_child_weight=5; total time= 3.2min
# [CV] END ....................max_depth=4, min_child_weight=5; total time= 3.2min
# [CV] END ....................max_depth=5, min_child_weight=2; total time= 4.5min
# [CV] END ....................max_depth=5, min_child_weight=2; total time= 4.5min
# [CV] END ....................max_depth=5, min_child_weight=1; total time= 4.6min
# [CV] END ....................max_depth=5, min_child_weight=1; total time= 4.6min
# [CV] END ....................max_depth=5, min_child_weight=3; total time= 4.0min
# [CV] END ....................max_depth=5, min_child_weight=3; total time= 4.0min
# [CV] END ....................max_depth=5, min_child_weight=4; total time= 3.5min
# [CV] END ....................max_depth=5, min_child_weight=4; total time= 3.6min
# [CV] END ....................max_depth=5, min_child_weight=5; total time= 2.6min
# [CV] END ....................max_depth=5, min_child_weight=5; total time= 2.6min
#
# Best: 0.543198 using {'max_depth': 5, 'min_child_weight': 3}
#
# 0.505981 (0.003600) with: {'max_depth': 3, 'min_child_weight': 1}
# 0.504533 (0.003714) with: {'max_depth': 3, 'min_child_weight': 2}
# 0.503086 (0.003676) with: {'max_depth': 3, 'min_child_weight': 3}
# 0.504305 (0.002152) with: {'max_depth': 3, 'min_child_weight': 4}
# 0.506076 (0.005105) with: {'max_depth': 3, 'min_child_weight': 5}
# 0.526666 (0.002419) with: {'max_depth': 4, 'min_child_weight': 1}
# 0.522513 (0.002152) with: {'max_depth': 4, 'min_child_weight': 2}
# 0.526342 (0.001448) with: {'max_depth': 4, 'min_child_weight': 3}
# 0.528627 (0.002514) with: {'max_depth': 4, 'min_child_weight': 4}
# 0.526132 (0.003028) with: {'max_depth': 4, 'min_child_weight': 5}
# 0.542798 (0.001371) with: {'max_depth': 5, 'min_child_weight': 1}
# 0.540627 (0.003009) with: {'max_depth': 5, 'min_child_weight': 2}
# 0.543198 (0.002800) with: {'max_depth': 5, 'min_child_weight': 3}
# 0.541998 (0.002819) with: {'max_depth': 5, 'min_child_weight': 4}
# 0.541617 (0.000000) with: {'max_depth': 5, 'min_child_weight': 5}
# [0]	train-logloss:0.65551+0.00001	test-logloss:0.65590+0.00012
# [50]	train-logloss:0.39829+0.00005	test-logloss:0.41257+0.00106
# [100]	train-logloss:0.37580+0.00096	test-logloss:0.40595+0.00079
# [150]	train-logloss:0.35679+0.00143	test-logloss:0.40257+0.00018
# [200]	train-logloss:0.34042+0.00154	test-logloss:0.40051+0.00041
# [250]	train-logloss:0.32486+0.00139	test-logloss:0.39918+0.00067
# [300]	train-logloss:0.31117+0.00132	test-logloss:0.39796+0.00059
# [350]	train-logloss:0.29879+0.00106	test-logloss:0.39726+0.00096
# [400]	train-logloss:0.28656+0.00102	test-logloss:0.39649+0.00093
# [450]	train-logloss:0.27621+0.00059	test-logloss:0.39638+0.00116
# [457]	train-logloss:0.27483+0.00045	test-logloss:0.39639+0.00120
# Updated params :  {'max_depth': 5, 'eta': 0.1, 'objective': 'binary:logistic', 'min_child_weight': 3, 'gamma': 0, 'nthread': 4, 'scale_pos_weight': 1, 'subsample': 1, 'colsample_bytree': 1, 'seed': 27}
# Updated number of trees :  408
#
# Step 3 : Tune gamma...
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# [CV] END ..........................................gamma=0.1; total time= 2.7min
# [CV] END ..........................................gamma=0.0; total time= 2.7min
# [CV] END ..........................................gamma=0.2; total time= 2.7min
# [CV] END ..........................................gamma=0.1; total time= 2.7min
# [CV] END ..........................................gamma=0.0; total time= 2.7min
# [CV] END ..........................................gamma=0.2; total time= 2.7min
#
# Best: 0.534799 using {'gamma': 0.2}
#
# 0.533789 (0.001924) with: {'gamma': 0.0}
# 0.533523 (0.000362) with: {'gamma': 0.1}
# 0.534799 (0.003352) with: {'gamma': 0.2}
# [0]	train-logloss:0.65551+0.00001	test-logloss:0.65590+0.00012
# [50]	train-logloss:0.39856+0.00003	test-logloss:0.41273+0.00096
# [100]	train-logloss:0.37605+0.00083	test-logloss:0.40631+0.00070
# [150]	train-logloss:0.35588+0.00087	test-logloss:0.40221+0.00050
# [200]	train-logloss:0.33918+0.00117	test-logloss:0.39999+0.00078
# [250]	train-logloss:0.32386+0.00137	test-logloss:0.39854+0.00084
# [300]	train-logloss:0.31041+0.00141	test-logloss:0.39755+0.00080
# [350]	train-logloss:0.29753+0.00153	test-logloss:0.39654+0.00077
# [400]	train-logloss:0.28567+0.00176	test-logloss:0.39613+0.00068
# [450]	train-logloss:0.27499+0.00183	test-logloss:0.39600+0.00078
# [472]	train-logloss:0.27087+0.00190	test-logloss:0.39597+0.00072
# Updated params :  {'max_depth': 5, 'eta': 0.1, 'objective': 'binary:logistic', 'min_child_weight': 3, 'gamma': 0.2, 'nthread': 4, 'scale_pos_weight': 1, 'subsample': 1, 'colsample_bytree': 1, 'seed': 27}
# Updated number of trees :  424
#
# Step 4 : Tune regularization parameters...
# Fitting 2 folds for each of 12 candidates, totalling 24 fits
# [CV] END .......................reg_alpha=0, reg_lambda=0.01; total time= 3.7min
# [CV] END ........................reg_alpha=0, reg_lambda=0.1; total time= 3.7min
# [CV] END .......................reg_alpha=0, reg_lambda=0.01; total time= 3.7min
# [CV] END ..........................reg_alpha=0, reg_lambda=0; total time= 3.7min
# [CV] END ..........................reg_alpha=0, reg_lambda=0; total time= 3.7min
# [CV] END ........................reg_alpha=0, reg_lambda=0.1; total time= 3.7min
# [CV] END ..........................reg_alpha=0, reg_lambda=1; total time= 3.7min
# [CV] END ..........................reg_alpha=0, reg_lambda=1; total time= 3.7min
# [CV] END .....................reg_alpha=0.1, reg_lambda=0.01; total time= 3.6min
# [CV] END ........................reg_alpha=0.1, reg_lambda=0; total time= 3.6min
# [CV] END .....................reg_alpha=0.1, reg_lambda=0.01; total time= 3.6min
# [CV] END ........................reg_alpha=0.1, reg_lambda=0; total time= 3.6min
# [CV] END ......................reg_alpha=0.1, reg_lambda=0.1; total time= 3.6min
# [CV] END ......................reg_alpha=0.1, reg_lambda=0.1; total time= 3.6min
# [CV] END ........................reg_alpha=0.1, reg_lambda=1; total time= 3.7min
# [CV] END ........................reg_alpha=0.1, reg_lambda=1; total time= 3.7min
# [CV] END ..........................reg_alpha=1, reg_lambda=0; total time= 3.4min
# [CV] END ..........................reg_alpha=1, reg_lambda=0; total time= 3.5min
# [CV] END .......................reg_alpha=1, reg_lambda=0.01; total time= 3.5min
# [CV] END .......................reg_alpha=1, reg_lambda=0.01; total time= 3.5min
# [CV] END ........................reg_alpha=1, reg_lambda=0.1; total time= 3.4min
# [CV] END ........................reg_alpha=1, reg_lambda=0.1; total time= 3.4min
# [CV] END ..........................reg_alpha=1, reg_lambda=1; total time= 3.4min
# [CV] END ..........................reg_alpha=1, reg_lambda=1; total time= 3.4min
#
# Best: 0.542341 using {'reg_alpha': 1, 'reg_lambda': 0}
#
# 0.535046 (0.000438) with: {'reg_alpha': 0, 'reg_lambda': 0}
# 0.532970 (0.001562) with: {'reg_alpha': 0, 'reg_lambda': 0.01}
# 0.536056 (0.001295) with: {'reg_alpha': 0, 'reg_lambda': 0.1}
# 0.536170 (0.001905) with: {'reg_alpha': 0, 'reg_lambda': 1}
# 0.536303 (0.001048) with: {'reg_alpha': 0.1, 'reg_lambda': 0}
# 0.533961 (0.000419) with: {'reg_alpha': 0.1, 'reg_lambda': 0.01}
# 0.538303 (0.000267) with: {'reg_alpha': 0.1, 'reg_lambda': 0.1}
# 0.534456 (0.001981) with: {'reg_alpha': 0.1, 'reg_lambda': 1}
# 0.542341 (0.001905) with: {'reg_alpha': 1, 'reg_lambda': 0}
# 0.541675 (0.000171) with: {'reg_alpha': 1, 'reg_lambda': 0.01}
# 0.542246 (0.000210) with: {'reg_alpha': 1, 'reg_lambda': 0.1}
# 0.538551 (0.002267) with: {'reg_alpha': 1, 'reg_lambda': 1}
# [0]	train-logloss:0.65548+0.00000	test-logloss:0.65585+0.00013
# [50]	train-logloss:0.39802+0.00047	test-logloss:0.41267+0.00074
# [100]	train-logloss:0.37187+0.00102	test-logloss:0.40524+0.00038
# [150]	train-logloss:0.35107+0.00086	test-logloss:0.40154+0.00040
# [200]	train-logloss:0.33235+0.00101	test-logloss:0.39913+0.00048
# [250]	train-logloss:0.31584+0.00100	test-logloss:0.39756+0.00038
# [300]	train-logloss:0.30066+0.00118	test-logloss:0.39639+0.00056
# [350]	train-logloss:0.28677+0.00083	test-logloss:0.39579+0.00090
# [400]	train-logloss:0.27409+0.00059	test-logloss:0.39532+0.00126
# [450]	train-logloss:0.26254+0.00087	test-logloss:0.39520+0.00150
# [500]	train-logloss:0.25176+0.00095	test-logloss:0.39529+0.00167
# [520]	train-logloss:0.24770+0.00080	test-logloss:0.39533+0.00184
# Updated params :  {'max_depth': 5, 'eta': 0.1, 'objective': 'binary:logistic', 'min_child_weight': 3, 'gamma': 0.2, 'nthread': 4, 'scale_pos_weight': 1, 'subsample': 1, 'colsample_bytree': 1, 'seed': 27, 'reg_alpha': 1, 'reg_lambda': 0}
# Updated number of trees :  471
#
# Step 5 : Tune subsample and colsample_bytree...
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# [CV] END ..................colsample_bytree=0.8, subsample=1; total time= 3.0min
# [CV] END ..................colsample_bytree=0.8, subsample=1; total time= 3.1min
# [CV] END ................colsample_bytree=0.8, subsample=0.8; total time= 3.1min
# [CV] END ................colsample_bytree=0.8, subsample=0.8; total time= 3.1min
# [CV] END ................colsample_bytree=0.8, subsample=0.9; total time= 3.1min
# [CV] END ................colsample_bytree=0.8, subsample=0.9; total time= 3.1min
# [CV] END ................colsample_bytree=0.9, subsample=0.8; total time= 3.2min
# [CV] END ................colsample_bytree=0.9, subsample=0.8; total time= 3.2min
# [CV] END ................colsample_bytree=0.9, subsample=0.9; total time= 3.9min
# [CV] END ..................colsample_bytree=0.9, subsample=1; total time= 3.9min
# [CV] END ................colsample_bytree=0.9, subsample=0.9; total time= 3.9min
# [CV] END ..................colsample_bytree=0.9, subsample=1; total time= 3.9min
# [CV] END ..................colsample_bytree=1, subsample=0.8; total time= 3.9min
# [CV] END ..................colsample_bytree=1, subsample=0.8; total time= 4.0min
# [CV] END ..................colsample_bytree=1, subsample=0.9; total time= 3.9min
# [CV] END ..................colsample_bytree=1, subsample=0.9; total time= 3.9min
# [CV] END ....................colsample_bytree=1, subsample=1; total time= 1.2min
# [CV] END ....................colsample_bytree=1, subsample=1; total time= 1.2min
#
# Best: 0.551655 using {'colsample_bytree': 0.9, 'subsample': 0.9}
#
# 0.548684 (0.002305) with: {'colsample_bytree': 0.8, 'subsample': 0.8}
# 0.551636 (0.001448) with: {'colsample_bytree': 0.8, 'subsample': 0.9}
# 0.543941 (0.000381) with: {'colsample_bytree': 0.8, 'subsample': 1}
# 0.550036 (0.001333) with: {'colsample_bytree': 0.9, 'subsample': 0.8}
# 0.551655 (0.001695) with: {'colsample_bytree': 0.9, 'subsample': 0.9}
# 0.547179 (0.000762) with: {'colsample_bytree': 0.9, 'subsample': 1}
# 0.548189 (0.001581) with: {'colsample_bytree': 1, 'subsample': 0.8}
# 0.551465 (0.000362) with: {'colsample_bytree': 1, 'subsample': 0.9}
# 0.546417 (0.002400) with: {'colsample_bytree': 1, 'subsample': 1}
# [0]	train-logloss:0.65564+0.00013	test-logloss:0.65601+0.00005
# [50]	train-logloss:0.39784+0.00062	test-logloss:0.41306+0.00080
# [100]	train-logloss:0.37039+0.00122	test-logloss:0.40497+0.00057
# [150]	train-logloss:0.34893+0.00136	test-logloss:0.40154+0.00057
# [200]	train-logloss:0.33037+0.00100	test-logloss:0.39946+0.00103
# [250]	train-logloss:0.31397+0.00102	test-logloss:0.39758+0.00088
# [300]	train-logloss:0.29871+0.00078	test-logloss:0.39678+0.00102
# [350]	train-logloss:0.28501+0.00045	test-logloss:0.39622+0.00099
# [400]	train-logloss:0.27217+0.00051	test-logloss:0.39566+0.00097
# [450]	train-logloss:0.26061+0.00017	test-logloss:0.39524+0.00109
# [500]	train-logloss:0.24917+0.00000	test-logloss:0.39527+0.00139
# [509]	train-logloss:0.24734+0.00003	test-logloss:0.39519+0.00135
# Updated params :  {'max_depth': 5, 'eta': 0.1, 'objective': 'binary:logistic', 'min_child_weight': 3, 'gamma': 0.2, 'nthread': 4, 'scale_pos_weight': 1, 'subsample': 0.9, 'colsample_bytree': 0.9, 'seed': 27, 'reg_alpha': 1, 'reg_lambda': 0}
# Updated number of trees :  461
#
# Step 6 : Reducing learning rate and tune number of trees parameter...
# [0]	train-logloss:0.68922+0.00001	test-logloss:0.68926+0.00000
# [500]	train-logloss:0.39814+0.00074	test-logloss:0.41280+0.00047
# [1000]	train-logloss:0.37100+0.00111	test-logloss:0.40426+0.00048
# [1500]	train-logloss:0.34901+0.00122	test-logloss:0.40008+0.00046
# [2000]	train-logloss:0.32972+0.00134	test-logloss:0.39710+0.00060
# [2500]	train-logloss:0.31266+0.00129	test-logloss:0.39510+0.00075
# [3000]	train-logloss:0.29743+0.00123	test-logloss:0.39362+0.00087
# [3500]	train-logloss:0.28339+0.00118	test-logloss:0.39246+0.00098
# [4000]	train-logloss:0.27052+0.00109	test-logloss:0.39166+0.00110
# [4500]	train-logloss:0.25882+0.00106	test-logloss:0.39113+0.00120
# [5000]	train-logloss:0.24789+0.00090	test-logloss:0.39083+0.00129
# [5500]	train-logloss:0.23775+0.00082	test-logloss:0.39068+0.00133
# [6000]	train-logloss:0.22820+0.00076	test-logloss:0.39071+0.00141
# [6103]	train-logloss:0.22628+0.00079	test-logloss:0.39073+0.00142
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/gonzalez/Documents/schneider_electric/xgboost_modeling_pca.ipynb Cell 4' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/gonzalez/Documents/schneider_electric/xgboost_modeling_pca.ipynb#ch0000004?line=0'>1</a> best_model = do_workflow(
#       <a href='vscode-notebook-cell:/Users/gonzalez/Documents/schneider_electric/xgboost_modeling_pca.ipynb#ch0000004?line=1'>2</a>         dftrain=x_train,
#       <a href='vscode-notebook-cell:/Users/gonzalez/Documents/schneider_electric/xgboost_modeling_pca.ipynb#ch0000004?line=2'>3</a>         y_train=y_train,
#       <a href='vscode-notebook-cell:/Users/gonzalez/Documents/schneider_electric/xgboost_modeling_pca.ipynb#ch0000004?line=3'>4</a>         dftest=x_val,
#       <a href='vscode-notebook-cell:/Users/gonzalez/Documents/schneider_electric/xgboost_modeling_pca.ipynb#ch0000004?line=4'>5</a>         y_test=y_val,
#       <a href='vscode-notebook-cell:/Users/gonzalez/Documents/schneider_electric/xgboost_modeling_pca.ipynb#ch0000004?line=5'>6</a>         kfolds=2,
#       <a href='vscode-notebook-cell:/Users/gonzalez/Documents/schneider_electric/xgboost_modeling_pca.ipynb#ch0000004?line=6'>7</a>     )
#
# File ~/Documents/schneider_electric/workflow.py:182, in do_workflow(dftrain, y_train, dftest, y_test, kfolds)
#     <a href='file:///~/Documents/schneider_electric/workflow.py?line=179'>180</a> # model predictions on test datas
#     <a href='file:///~/Documents/schneider_electric/workflow.py?line=180'>181</a> preds = bst.predict(xgtest)
# --> <a href='file:///~/Documents/schneider_electric/workflow.py?line=181'>182</a> predictions = [round(value) for value in preds]
#     <a href='file:///~/Documents/schneider_electric/workflow.py?line=183'>184</a> accuracy = multi_class_accuracy(preds, y_test)
#     <a href='file:///~/Documents/schneider_electric/workflow.py?line=184'>185</a> print("\nFinal number of trees : ", num_boost_round)
#
# File ~/Documents/schneider_electric/workflow.py:182, in <listcomp>(.0)
#     <a href='file:///~/Documents/schneider_electric/workflow.py?line=179'>180</a> # model predictions on test datas
#     <a href='file:///~/Documents/schneider_electric/workflow.py?line=180'>181</a> preds = bst.predict(xgtest)
# --> <a href='file:///~/Documents/schneider_electric/workflow.py?line=181'>182</a> predictions = [round(value) for value in preds]
#     <a href='file:///~/Documents/schneider_electric/workflow.py?line=183'>184</a> accuracy = multi_class_accuracy(preds, y_test)
#     <a href='file:///~/Documents/schneider_electric/workflow.py?line=184'>185</a> print("\nFinal number of trees : ", num_boost_round)
#
# TypeError: type numpy.ndarray doesn't define __round__ method

# %%
# Validation accuracy
def multi_class_accuracy(preds, gt):
    hits = 0
    for i in range(gt.shape[0]):
        gt_label = np.argmax(gt[i])
        pred_label = np.argmax(preds[i])
        if gt_label==pred_label: hits+=1
    return hits/gt.shape[0]

bst = xgb.Booster()  # init model
bst.load_model('0001.model')  # load data
xgtest = xgb.DMatrix(x_val.values, feature_names=x_val.keys().values)
preds = bst.predict(xgtest)
print("Validation accuracy", multi_class_accuracy(preds, y_val))
xgtrain = xgb.DMatrix(x_train.values, feature_names=x_train.keys().values)
preds = bst.predict(xgtrain)
print("Training accuracy", multi_class_accuracy(preds, y_train))
# Out:
# Validation accuracy 0.6769008075575195
# Training accuracy 0.89387070968725

# %%
# Generate the predictions csv with the best model
df_test = pd.read_csv("clean_test_reduced.csv")
test_index = list(df_test["test_index"])
df_test.drop(columns = "test_index", inplace = True) # Drop index to predict
xgtest = xgb.DMatrix(df_test.values, feature_names=df_test.keys().values)

preds = bst.predict(xgtest)
predictions=[np.argmax(preds[i]) for i in range(len(preds))]
for i in range(len(predictions)): # Transform to the required format
    if predictions[i] == 0: predictions[i] = 2
    elif predictions[i] == 1: predictions[i] = 0
    elif predictions[i] == 2: predictions[i] = 1
preds_df = pd.DataFrame(data = {'test_index': test_index, "pollutant": predictions})

preds_df.to_csv("predictions.csv", index = False) # Save predictions
preds_df.to_json('predictions.json')
