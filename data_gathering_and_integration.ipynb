# %%
# IMPORTS
import pandas as pd
import textract
import glob
from collections import Counter
# To parse pdfs
import io
from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.layout import LAParams
from pdfminer.converter import TextConverter
from pdfminer.pdfinterp import PDFPageInterpreter
from pdfminer.pdfpage import PDFPage

# %% [markdown]
# ### Read first CSV and append the rest to it to form the general training dataset

# %%
total_df = pd.read_csv("data/train1.csv")
df2 = pd.read_csv("data/train2.csv", sep = ";")
print((total_df.columns == df2.columns).all())
total_df = pd.concat((total_df, df2), ignore_index = True)
print(total_df.shape)
total_df.head()
# Out:
# True
# (37127, 21)
#   countryName                  eprtrSectorName  \
# 0     Germany                 Mineral industry
# 1       Italy                 Mineral industry
# 2       Spain  Waste and wastewater management
# 3     Czechia                    Energy sector
# 4     Finland  Waste and wastewater management
#
#                         EPRTRAnnexIMainActivityLabel  \
# 0  Installations for the production of cement cli...
# 1  Installations for the production of cement cli...
# 2  Landfills (excluding landfills of inert waste ...
# 3  Thermal power stations and other combustion in...
# 4                 Urban waste-water treatment plants
#
#                                    FacilityInspireID  \
# 0  https://registry.gdi-de.org/id/de.ni.mu/062217...
# 1                         IT.CAED/240602021.FACILITY
# 2                         ES.CAED/001966000.FACILITY
# 3                    CZ.MZP.U422/CZ34736841.FACILITY
# 4  http://paikkatiedot.fi/so/1002031/pf/Productio...
#
#                                         facilityName                  City  \
# 0               Holcim (Deutschland) GmbH Werk Höver                Sehnde
# 1               Stabilimento di Tavernola Bergamasca  TAVERNOLA BERGAMASCA
# 2                  COMPLEJO MEDIOAMBIENTAL DE ZURITA    PUERTO DEL ROSARIO
# 3                                Elektrárny Prunéřov                 Kadaň
# 4  TAMPEREEN VESI LIIKELAITOS, VIINIKANLAHDEN JÄT...               Tampere
#
#   targetRelease              pollutant  reportingYear  MONTH  ...  CONTINENT  \
# 0           AIR   Carbon dioxide (CO2)           2015     10  ...     EUROPE
# 1           AIR  Nitrogen oxides (NOX)           2018      9  ...     EUROPE
# 2           AIR          Methane (CH4)           2019      2  ...     EUROPE
# 3           AIR  Nitrogen oxides (NOX)           2012      8  ...     EUROPE
# 4           AIR          Methane (CH4)           2018     12  ...     EUROPE
#
#   max_wind_speed  avg_wind_speed  min_wind_speed   max_temp   avg_temp  \
# 0      15.118767       14.312541       21.419106   2.864895   4.924169
# 1      19.661550       19.368166       21.756389   5.462839   7.864403
# 2      12.729453       14.701985       17.103930   1.511201   4.233438
# 3      11.856417       16.122584       17.537184  10.970301  10.298348
# 4      17.111930       20.201604       21.536012  11.772039  11.344078
#
#     min_temp  DAY WITH FOGS     REPORTER NAME  \
# 0   9.688206              2  Mr. Jacob Ortega
# 1  12.023521              1    Ashlee Serrano
# 2   8.632193              2      Vincent Kemp
# 3  15.179215              0        Carol Gray
# 4  16.039004              2        Blake Ford
#
#                             CITY ID
# 0  7cdb5e74adcb2ffaa21c1b61395a984f
# 1  cd1dbabbdba230b828c657a9b19a8963
# 2  5011e3fa1436d15b34f1287f312fbada
# 3  37a6d7a71c4f7c2469e4f01b70dd90c2
# 4  471fe554e1c62d1b01cc8e4e5076c61a
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Download data from API and concat to the csv data

# %%
API_urls = "http://schneiderapihack-env.eba-3ais9akk.us-east-2.elasticbeanstalk.com/"
API_urls = [API_urls + "first", API_urls + "second", API_urls + "third"]

for i, url in enumerate(API_urls):
    data = pd.read_json(url)
    print("API", i + 1 , "concatenaing", len(data), "rows")
    data.drop(columns = ["", "EPRTRAnnexIMainActivityCode", "EPRTRSectorCode"], inplace = True) # Drop redundant columns
    # Concat to total df
    total_df = pd.concat((total_df, data), ignore_index = True)

print("Final shape after concatenating APIs", total_df.shape)
# Out:
# API 1 concatenaing 9500 rows
# API 2 concatenaing 9500 rows
# API 3 concatenaing 9501 rows
# Final shape after concatenating APIs (65628, 21)

# %%
# Save dataframe
total_df.to_csv("total_df.csv", index = False)

# %% [markdown]
# ### Parse PDFs

# %%
def pdf_to_text(path):
    with open(path, 'rb') as fp:
        rsrcmgr = PDFResourceManager()
        outfp = io.StringIO()
        laparams = LAParams()
        device = TextConverter(rsrcmgr, outfp, laparams=laparams)
        interpreter = PDFPageInterpreter(rsrcmgr, device)
        for page in PDFPage.get_pages(fp):
            interpreter.process_page(page)
    text = outfp.getvalue()
    return text

# %%
def select_meaningful_lines(text, print_raw=False):
    # Remove some specific lines that induce problems
    for i in range(len(text)):
        if text[i] == 'nº:': n_ind = i
    text = text[:n_ind-1]+text[n_ind+5:]

    if print_raw: print([(i, text[i]) for i in range(len(text))]) # Print each line with the corresponding index
    text = [text[i] for i in [2, 3, 8, 9, 13, 17, 19, 21, 26, 28, 32, 36, 40, 42, 46, 50, 54, 58, 60, 64, 66, 70]]
    return text

def clean_lines(text):
    text.append(text[15].split(" ")[0])
    text[12], text[17], text[15] = text[12].split(" ")[0], text[17].split(" ")[0], text[15].split(":")[1]
    text = [text[i].split(":")[-1].lstrip() for i in range(len(text))] # Eliminate the name of the field like "name:" if there is any
    return text

['countryName', 'eprtrSectorName', 'EPRTRAnnexIMainActivityLabel',
       'FacilityInspireID', 'facilityName', 'City', 'targetRelease',
       'pollutant', 'reportingYear', 'MONTH', 'DAY', 'CONTINENT',
       'max_wind_speed', 'avg_wind_speed', 'min_wind_speed', 'max_temp',
       'avg_temp', 'min_temp', 'DAY WITH FOGS', 'REPORTER NAME', 'CITY ID',
       'EPRTRAnnexIMainActivityCode', 'EPRTRSectorCode']

def create_df(fields):
    """ Add column names to each of the extracted fields"""
    # Field names in the order they are received
    field_names = ["facilityName", "FacilityInspireID", "countryName", "City", "CONTINENT", "EPRTRSectorCode", "eprtrSectorName",
            "EPRTRAnnexIMainActivityCode", "targetRelease", "emissions", "pollutant", "DAY", "MONTH", "reportingYear", "max_wind_speed",
            "avg_wind_speed", "max_temp", "min_temp", "avg_temp", "DAY WITH FOGS", "REPORTER NAME", "CITY ID", "min_wind_speed"]
    return pd.DataFrame(data=dict(zip(field_names,fields)), index = [0])

pdf_filenames = glob.glob("data/train6/*") # Read filenames

for i, pdf_filename in enumerate(pdf_filenames):
    text = pdf_to_text(pdf_filename) # Get the text from the pdf
    text = text.split("\n") 
    if len(text) != 79:
        continue
    fields = select_meaningful_lines(text)
    # Split some fields that have been merged in the decoding
    clean_fields = clean_lines(fields)
    df = create_df(clean_fields)
    #if i == 0: # Print process for the first pdf
    if i==0:
        pdf_dfs = df
        print("Select fields with relevant info")
        print(fields)
        print("Clean fields")
        print(clean_fields)
        print("Extraxted df")
    else:
        if df.loc[0, "countryName"] != "":
            pdf_dfs = pd.concat((pdf_dfs, df), ignore_index = True)

display(pdf_dfs)

print("From", len(pdf_filenames), "PDFs,", len(pdf_dfs), "could be parsed")
total_df = pd.concat((total_df, pdf_dfs), ignore_index = True) # Concat to general dataframe
print("Final shape after concatenating APIs", total_df.shape)
# Out:
# Select fields with relevant info
# ['FACILITY NAME: Greenoakhill Landfill Site, Glasgow', 'FacilityInspireID: UK.SEPA/200000110.Facility', 'United Kingdom', 'Mount Vernon', 'EUROPE', '5', 'eprtrSectorName: Waste and wastewater management', 'MainActivityCode: 5(d)', 'AIR', '1910000', 'Methane (CH4)', '14', '3', '2019', 'max_wind_speed: 1,44E+16', ' 1,47E+16', '1,61E+16', '1,77E+15', '1,61E+16', '7', 'REPORTER NAME:Jodi Holden', '5a9cc0e1663ad226675e57387c5e24e6', '1,7E+15']
# Clean fields
# ['Greenoakhill Landfill Site, Glasgow', 'UK.SEPA/200000110.Facility', 'United Kingdom', 'Mount Vernon', 'EUROPE', '5', 'Waste and wastewater management', '5(d)', 'AIR', '1910000', 'Methane (CH4)', '14', '3', '2019', '1,44E+16', '1,47E+16', '1,61E+16', '1,77E+15', '1,61E+16', '7', 'Jodi Holden', '5a9cc0e1663ad226675e57387c5e24e6', '1,7E+15']
# Extraxted df
#                              facilityName           FacilityInspireID  \
# 0     Greenoakhill Landfill Site, Glasgow  UK.SEPA/200000110.Facility
# 1       Auchencarroch Landfill, Jamestown  UK.SEPA/200000083.Facility
# 2          Garlaff Landfill Site, Cumnock  UK.SEPA/200000084.Facility
# 3                Auchenlosh Landfill Site  UK.SEPA/200000082.Facility
# 4     Auchinlea Landfill Site, Motherwell  UK.SEPA/200000109.Facility
# 5           Nether Dallachy Landfill Site  UK.SEPA/200000106.Facility
# 6                     Alloa Glass Factory  UK.SEPA/200000073.Facility
# 7              Dalmacoulter Landfill Site  UK.SEPA/200002314.Facility
# 8    Dalinlongart Landfill Site, Sandbank  UK.SEPA/200001325.Facility
# 9       Greengairs Landfill Site, Airdrie  UK.SEPA/200000116.Facility
# 10                UK Waste Management Ltd  UK.SEPA/200002311.Facility
# 11     Dunbar Landfill Site, East Lothian  UK.SEPA/200000123.Facility
# 12                   Markinch Biomass CHP  UK.SEPA/200002509.Facility
# 13  Oatslie Sandpit Landfill Site, Roslin  UK.SEPA/200000127.Facility
# 14        Dunbar Energy Recovery Facility  UK.SEPA/200002618.Facility
# 15                 Gremista Landfill Site  UK.SEPA/200001641.Facility
# 16         Moleigh Landfill Site, Ariogan  UK.SEPA/200001590.Facility
# 17                   Duisky Landfill Site  UK.SEPA/200001608.Facility
# 18        Avondale Landfill Site, Polmont  UK.SEPA/200000115.Facility
# 19        Avondale Landfill Site, Polmont  UK.SEPA/200000115.Facility
#
#        countryName                              City CONTINENT  \
# 0   United Kingdom                      Mount Vernon    EUROPE
# 1   United Kingdom                        Alexandria    EUROPE
# 2   United Kingdom                           Cumnock    EUROPE
# 3   United Kingdom                        Dalbeattie    EUROPE
# 4   United Kingdom                          Clelland    EUROPE
# 5   United Kingdom                          Spey Bay    EUROPE
# 6   United Kingdom                             Alloa    EUROPE
# 7   United Kingdom                       Dalmacouter    EUROPE
# 8   United Kingdom                            Dunoon    EUROPE
# 9   United Kingdom                           Airdrie    EUROPE
# 10  United Kingdom                          Wellbank    EUROPE
# 11  United Kingdom                            Dunbar    EUROPE
# 12  United Kingdom                        Glenrothes    EUROPE
# 13  United Kingdom                            Roslin    EUROPE
# 14  United Kingdom  East Barns, Dunbar, East Lothian    EUROPE
# 15  United Kingdom                           Lerwick    EUROPE
# 16  United Kingdom                           by Oban    EUROPE
# 17  United Kingdom                      Fort William    EUROPE
# 18  United Kingdom                           Polmont    EUROPE
# 19  United Kingdom                           Polmont    EUROPE
#
#    EPRTRSectorCode                  eprtrSectorName  \
# 0                5  Waste and wastewater management
# 1                5  Waste and wastewater management
# 2                5  Waste and wastewater management
# 3                5  Waste and wastewater management
# 4                5  Waste and wastewater management
# 5                5  Waste and wastewater management
# 6                3                 Mineral industry
# 7                5  Waste and wastewater management
# 8                5  Waste and wastewater management
# 9                5  Waste and wastewater management
# 10               5  Waste and wastewater management
# 11               5  Waste and wastewater management
# 12               5  Waste and wastewater management
# 13               5  Waste and wastewater management
# 14               5  Waste and wastewater management
# 15               5  Waste and wastewater management
# 16               5  Waste and wastewater management
# 17               5  Waste and wastewater management
# 18               5  Waste and wastewater management
# 19               5  Waste and wastewater management
#
#    EPRTRAnnexIMainActivityCode targetRelease emissions  ... reportingYear  \
# 0                         5(d)           AIR   1910000  ...          2019
# 1                         5(d)           AIR   1300000  ...          2019
# 2                         5(d)        999000       AIR  ...          2019
# 3                         5(d)        101000       AIR  ...          2019
# 4                         5(d)        922000       AIR  ...          2019
# 5                         5(d)        945000       AIR  ...          2019
# 6                         3(e)        990000       AIR  ...          2019
# 7                         5(d)        104000       AIR  ...          2019
# 8                         5(d)        148000       AIR  ...          2019
# 9                         5(d)        972000       AIR  ...          2019
# 10                        5(d)        179000       AIR  ...          2019
# 11                        5(d)        740000       AIR  ...          2019
# 12                        5(b)        230000       AIR  ...          2019
# 13                        5(d)        288000       AIR  ...          2019
# 14                        5(b)        323000       AIR  ...          2019
# 15                        5(d)        229000       AIR  ...          2019
# 16                        5(d)        115000       AIR  ...          2019
# 17                        5(d)        211000       AIR  ...          2019
# 18                        5(d)        101000       AIR  ...          2019
# 19                        5(d)           AIR   2620000  ...          2019
#
#    max_wind_speed avg_wind_speed  max_temp  min_temp  avg_temp DAY WITH FOGS  \
# 0        1,44E+16       1,47E+16  1,61E+16  1,77E+15  1,61E+16             7
# 1        1,69E+16       1,79E+15  5,38E+15  1,18E+15  7,29E+15            12
# 2        1,49E+15       2,04E+16  1,58E+16   8,9E+15  4,32E+14            11
# 3        1,46E+16       1,47E+16  9,74E+15   1,1E+16  9,23E+15             2
# 4        1,76E+15       1,72E+16  1,21E+16  1,66E+16  1,24E+16            14
# 5        1,64E+16       1,82E+15  1,98E+14  2,04E+16  1,91E+16             7
# 6        1,74E+16       1,89E+16  5,82E+14  9,39E+15  6,09E+15            12
# 7        9,89E+15       1,52E+16  1,25E+16  1,75E+16  1,48E+16             5
# 8        1,58E+16       1,89E+15  1,04E+16   1,7E+16  1,23E+16             2
# 9        2,11E+15       2,16E+16   1,7E+15     2E+16  1,87E+15            19
# 10       1,18E+16       1,56E+16  7,44E+15  1,27E+16  8,78E+15            18
# 11       1,13E+15       1,57E+16  1,73E+15  1,97E+16  1,81E+16             5
# 12       1,08E+16       1,53E+16  -1,3E+16  5,43E+15  1,49E+16            10
# 13       1,83E+16       2,14E+16  7,82E+15  1,18E+15  8,43E+14             1
# 14       1,93E+16       1,87E+16  6,82E+15  1,37E+16  8,77E+15             1
# 15       1,79E+16       2,04E+15  9,67E+14   1,4E+16  1,24E+16             9
# 16       1,61E+16       1,73E+16  1,52E+16  2,04E+15  1,61E+16            18
# 17       9,43E+15       1,49E+16  8,92E+15  1,43E+15  1,16E+16            15
# 18       1,73E+16       1,65E+16  9,37E+15  1,12E+16    -2E+16             7
# 19       1,37E+16       1,56E+16  -1,7E+16  2,05E+16  5,11E+15             2
#
#          REPORTER NAME                           CITY ID min_wind_speed
# 0          Jodi Holden  5a9cc0e1663ad226675e57387c5e24e6        1,7E+15
# 1         Tracy Powell  a6bc8f85a33112c5beea4d357caad4cd       2,07E+16
# 2       Rebecca Brooks  b6ca640b7121ae2bf206ea088f6a4618       2,37E+16
# 3           Brian Sims  d52bec466f0edb76a6fc14c109598ba2        1,7E+16
# 4      Reginald Fisher  82403770c9ed79e39a23ca735c8d945e       2,26E+15
# 5       Emily Martinez  a05c92d590027b51608394c16aedc477       2,57E+16
# 6           Lance Hart  2cc8f54182c37b8907f534011ea01e6f       2,23E+15
# 7         Keith Holmes  20b790f3c89efe9244f4b79071f3d7c5       1,63E+16
# 8        Joshua Oliver  bc9dc084a859e6b840b69d6146c646df        2,4E+16
# 9     Zachary Randolph  12ab217b40114f8deef2237c7a4d37ae       2,73E+16
# 10     Valerie Simmons  2c3df26128c6000ec9b5120a7917a862       1,95E+16
# 11        Carol Hinton  559b680a0a185afb0230c1a41927c92b       1,75E+15
# 12         Shari Moore  007e670e3bc4ccd47d59d8c578e751cb       1,66E+15
# 13        William Cook  d6a5f9342439a677a4f2ac3492b13eb7       2,78E+16
# 14    Christopher Tate  6935acf68ac33c9c85ff634275880d97       2,67E+15
# 15  Edward Ferrell PhD  218e50104ad214eb8a6c59b289c32667       2,36E+15
# 16     Danielle Harris  4c1bf2665cc02ac5cc6eed478d54d36b       2,04E+16
# 17        Paul Jackson  586e5fa25c16bd09e3e9cfc7cc269360       2,28E+15
# 18     Hunter Davidson  941b15d27183b05e8e58e0fbc509e963       1,87E+16
# 19    Trevor Rodriguez  941b15d27183b05e8e58e0fbc509e963       2,29E+16
#
# [20 rows x 23 columns]
# From 82 PDFs, 20 could be parsed
# Final shape after concatenating APIs (65648, 24)

# %% [markdown]
# ### Save final df

# %%
total_df.columns
# Out:
# Index(['countryName', 'eprtrSectorName', 'EPRTRAnnexIMainActivityLabel',
#        'FacilityInspireID', 'facilityName', 'City', 'targetRelease',
#        'pollutant', 'reportingYear', 'MONTH', 'DAY', 'CONTINENT',
#        'max_wind_speed', 'avg_wind_speed', 'min_wind_speed', 'max_temp',
#        'avg_temp', 'min_temp', 'DAY WITH FOGS', 'REPORTER NAME', 'CITY ID',
#        'EPRTRSectorCode', 'EPRTRAnnexIMainActivityCode', 'emissions'],
#       dtype='object')
